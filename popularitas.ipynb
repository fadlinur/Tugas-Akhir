# %%
import pandas as pd
import re

# %%
data = pd.read_csv ("Crawling data.csv")

# %%
df = data

# %%
df = df.drop('date', axis=1)

# %%
df.head(50)
# Out:
#     Unnamed: 0               id  \
# 0            0  di_dimu54412940
# 1            1         Monkdz25
# 2            2  Presiden_Swasta
# 3            3  di_dimu54412940
# 4            4      okezonenews
# 5            5    Elena08041804
# 6            6        andystwn4
# 7            7          moomigi
# 8            8      mercifulove
# 9            9          DkHurek
# 10          10    catatanganjar
# 11          11  AdiJaya45860062
# 12          12    Aryprasetyo85
# 13          13      nusabalicom
# 14          14     Reza90472792
# 15          15  redemptionPapua
# 16          16     inilahdotcom
# 17          17       LokoJoyo81
# 18          18           xylans
# 19          19        Bisniscom
# 20          20  MasamuneMasamu2
# 21          21           Maad31
# 22          22      okezonenews
# 23          23     inilahdotcom
# 24          24         kumparan
# 25          25        andystwn4
# 26          26      Tejasukma71
# 27          27        andystwn4
# ...

# %%
df.to_csv("data.csv", index =False)

# %%
data = pd.read_csv ("data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0               id  \
# 0           0  di_dimu54412940
# 1           1         Monkdz25
# 2           2  Presiden_Swasta
# 3           3  di_dimu54412940
# 4           4      okezonenews
#
#                                                 text
# 0  Calon Presiden Indonesia Ganjar Pranowo bersil...
# 1  *KODE ALAM DAN TANDA ZAMAN SIAPA PRESIDEN RI K...
# 2  @ch_chotimah2 Dulu waktu AHY calon gubernur di...
# 3  Sang calon presiden Indonesia, Ganjar Pranowo ...
# 4  Banyak tokoh yang digadang-gadang jadi calon w...

# %%
df.tail()
# Out:
#       Unnamed: 0             id  \
# 3137        3137       devan_r7
# 3138        3138    ShenoWirang
# 3139        3139  cnbcindonesia
# 3140        3140   cerevisiatee
# 3141        3141     alessyeni_
#
#                                                    text
# 3137  Ganjar Capres 2024 pilihan rakyat Indonesia\n#...
# 3138  Dua hal yang bisa menjegal si "pembual" Anies ...
# 3139  Video: Naik Turun Elektabilitas Capres 2024 ht...
# 3140                capres 2024 https://t.co/0uFSg1xtAQ
# 3141              @likechizu KIM NAMJOON CAPRES 2024!!!

# %%
combined_data = pd.concat([df.head(), df.tail()])

# %%
print(combined_data)
# Out:
#       Unnamed: 0               id  \
# 0              0  di_dimu54412940
# 1              1         Monkdz25
# 2              2  Presiden_Swasta
# 3              3  di_dimu54412940
# 4              4      okezonenews
# 3137        3137         devan_r7
# 3138        3138      ShenoWirang
# 3139        3139    cnbcindonesia
# 3140        3140     cerevisiatee
# 3141        3141       alessyeni_
#
#                                                    text
# 0     Calon Presiden Indonesia Ganjar Pranowo bersil...
# 1     *KODE ALAM DAN TANDA ZAMAN SIAPA PRESIDEN RI K...
# 2     @ch_chotimah2 Dulu waktu AHY calon gubernur di...
# 3     Sang calon presiden Indonesia, Ganjar Pranowo ...
# 4     Banyak tokoh yang digadang-gadang jadi calon w...
# 3137  Ganjar Capres 2024 pilihan rakyat Indonesia\n#...
# 3138  Dua hal yang bisa menjegal si "pembual" Anies ...
# 3139  Video: Naik Turun Elektabilitas Capres 2024 ht...
# 3140                capres 2024 https://t.co/0uFSg1xtAQ
# ...
